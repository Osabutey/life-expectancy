# %% [markdown]
# ## Exploratory Data Analysis on the Life Expectancy Data from WHO by Group PDS-08
#  ### Emmanuel Akpe
#  ### Emmanuel Agyekum
#  ### Emmanuel Osabutey
#  ### Ernest Owusu

# %% [markdown]
# #### Importing the necessary libraries needed for our analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### importing the dataset

# %%
LifeExpectancyData=pd.read_csv('LifeExpectancyData.csv')

# %% [markdown]
# #### Understanding the Data.

# %%
LifeExpectancyData.head()
# Viewing the first few rows to check the general structure of the data
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
LifeExpectancyData.tail()
# viewing the last 5 rows to check the general structure of the data.
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
LifeExpectancyData.shape
# view number of rows and columns in the dataset
# Out:
# (2938, 22)

# %%
LifeExpectancyData.nunique()
# viewing the unique values in the dataset
# Out:
# Country                             193
# Year                                 16
# Status                                2
# Life expectancy                     362
# Adult Mortality                     425
# infant deaths                       209
# Alcohol                            1076
# percentage expenditure             2328
# Hepatitis B                          87
# Measles                             958
#  BMI                                608
# under-five deaths                   252
# Polio                                73
# Total expenditure                   818
# Diphtheria                           81
#  HIV/AIDS                           200
# GDP                                2490
# Population                         2278
#  thinness  1-19 years               200
#  thinness 5-9 years                 207
# Income composition of resources     625
# Schooling                           173
# dtype: int64

# %%
#Developing VRs Developed
lifeDeveloping=LifeExpectancyData[LifeExpectancyData.Status=='Developing']
lifeDeveloped=LifeExpectancyData[LifeExpectancyData.Status=='Developed']
lifeDeveloping.nunique()
# Out:
# Country                             161
# Year                                 16
# Status                                1
# Life expectancy                     350
# Adult Mortality                     422
# infant deaths                       209
# Alcohol                             861
# percentage expenditure             1908
# Hepatitis B                          87
# Measles                             879
#  BMI                                597
# under-five deaths                   252
# Polio                                73
# Total expenditure                   742
# Diphtheria                           81
#  HIV/AIDS                           200
# GDP                                2042
# Population                         1868
#  thinness  1-19 years               199
#  thinness 5-9 years                 207
# Income composition of resources     575
# Schooling                           149
# dtype: int64

# %%
LifeExpectancyData.info()
# check for the data columns, their type and whether they have missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
LifeExpectancyData.isna().sum()
# check the number of missing values for each column in the dataset
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# #### Data cleaning

# %%
column_mean=LifeExpectancyData.mean()

# %%
# we fill the missing values with the mean of each column
LifeExpectancyData1= LifeExpectancyData.fillna(column_mean)

# %%
LifeExpectancyData1.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# ####  Data Analysis
# We analysed our data with respect to Immunization factors, Economic factors, Health Issues, and Social factors and their relationship with Life Expectancy.

# %%
#Displaying the general correlation between the variables in the dataset in tabular form
LifeExpectancyData1.corr()
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.169623        -0.078861
# Life expectancy                  0.169623          1.000000        -0.696359
# Adult Mortality                 -0.078861         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196535         0.078747
# Alcohol                         -0.048168          0.391598        -0.190408
# percentage expenditure           0.031400          0.381791        -0.242814
# Hepatitis B                      0.089398          0.203771        -0.138591
# Measles                         -0.082493         -0.157574         0.031174
#  BMI                             0.108327          0.559255        -0.381449
# under-five deaths               -0.042937         -0.222503         0.094135
# Polio                            0.093820          0.461574        -0.272694
# ...

# %%
#Displaying the general correlation between the variables in the dataset in graphical form
import seaborn as sns
sns.heatmap(LifeExpectancyData1.corr())

# %%
#plotting a scatter diagram to show the general trend of the Life Expectancy over time.
plt.scatter(LifeExpectancyData1['Year'], LifeExpectancyData1['Life expectancy '])
plt.xlabel('Years')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
LifeExpectancyData.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
from scipy.interpolate import *
import seaborn as sns
# %matplotlib inline

# %%
# Relatinship between Life expectancy and Immunization factors
sns.pairplot(LifeExpectancyData1,
            x_vars=['Hepatitis B','Measles ','Diphtheria ' ,'Polio' ], 
            y_vars=['Life expectancy '],
           kind='reg' )

# %%
#Relationship between Economic factors and Life Expectancy
sns.pairplot(LifeExpectancyData1,
            x_vars=['percentage expenditure','GDP','Income composition of resources' ,'Total expenditure' ], 
            y_vars=['Life expectancy '],
           kind='reg' )

# %%
# Relationship between Life expectancy and mortality
sns.pairplot(LifeExpectancyData1,
            x_vars=['Adult Mortality','infant deaths','under-five deaths ' ], 
            y_vars=['Life expectancy '],
           kind='reg' )

# %%
# Relationship between Social factors and Life Expectancy
sns.pairplot(LifeExpectancyData1,
            x_vars=['Alcohol','Schooling' ], 
            y_vars=['Life expectancy '],
           kind='reg' )

# %%
# Relationship between Health factors and Life Expectancy
sns.pairplot(LifeExpectancyData1,
            x_vars=[' BMI ',' HIV/AIDS',' thinness  1-19 years' ,' thinness 5-9 years' ], 
            y_vars=['Life expectancy '],
           kind='reg' )
